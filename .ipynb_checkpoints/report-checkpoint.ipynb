# %% [markdown]
# 策略1:有套利机会，加杠杆；
# 策略2:不加杠杆的，寻找短期爆发的币。

# %% [markdown]
# 研究：大行情后，收益率走势；
# 山寨币短期爆发前是否有规律。

# %%
import os
import pandas as pd
import numpy as np
import time
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
from statsmodels.tsa.stattools import adfuller as adf_test
from DataRead import Read, Analysis, Plot, Report, TOP_VALUABLE_MARKETS
from DataQuery import Ticker, Kline, Query
from Tactic import MACD, SMA, MultiTacs, Tactic
from pyecharts.charts import Line, Bar

# %matplotlib inline

# %% [markdown]
# ## 主流币的走势

# %%
end_date=datetime.today()
days_range=30
start_date=end_date+timedelta(days=-days_range)
start_str=datetime.strftime(start_date, "%Y-%m-%d")
end_str=datetime.strftime(end_date, "%Y-%m-%d")
freq='1d'
markets = TOP_VALUABLE_MARKETS.copy()

report = Report()
analysis=Analysis()
plot=Plot()

df_top_mkts = report.report_markets_indicators(markets=markets, interval=freq, start=start_date, end=end_date)
line_daily_return=plot.lineplot_individual_returns(markets=markets,interval=freq,start=start_date,end=end_date)
line_accumulative_return=plot.lineplot_accumulative_returns(markets=markets,interval=freq,start=start_date,end=end_date)
# Out:
# ------------------------------
#
# 本次运行时间:2024-05-05 16:23:20
# <TRXUSDT-1d>数据量为<0>,不足以进行<交易量>趋势检验.
# <TRXUSDT-1d>数据量为<0>,不足以进行<相对价格>趋势检验.
#
#
# done!

# %% [markdown]
# ### 简单统计

# %%
print('<{start}> 至 <{end}> 期间走势如下:'.format(start=start_str, end=end_str))
df_top_mkts.dropna()
# Out:
# <2024-04-05> 至 <2024-05-05> 期间走势如下:
#          货币名称     平均收益率   累计收益率     收益波动率   波动率(年化)     交易量趋势 相对BTC价格趋势
# 0     BTCUSDT -0.002800 -0.0840  0.027937  0.153018      趋势减少       无变化
# 1     ETHUSDT -0.002680 -0.0804  0.034423  0.188542      趋势减少      趋势增加
# 2     BNBUSDT -0.000243 -0.0073  0.025822  0.141432  没有明显变化趋势      趋势增加
# 3     SOLUSDT -0.007117 -0.2135  0.049985  0.273778      趋势减少      趋势减少
# 4     XRPUSDT -0.003883 -0.1165  0.038933  0.213244      趋势减少      趋势减少
# 5    DOGEUSDT -0.005553 -0.1666  0.053228  0.291544      趋势减少      趋势减少
# 6     ADAUSDT -0.008140 -0.2442  0.045433  0.248846      趋势减少      趋势减少
# 7    SHIBUSDT -0.003557 -0.1067  0.054096  0.296295      趋势减少      趋势增加
# 8    AVAXUSDT -0.008667 -0.2600  0.057622  0.315609      趋势减少      趋势减少
# 10    DOTUSDT -0.006127 -0.1838  0.047828  0.261963      趋势减少      趋势减少
# 11    BCHUSDT -0.013910 -0.4173  0.047268  0.258897      趋势减少      趋势减少
# 12   LINKUSDT -0.007010 -0.2103  0.047525  0.260303      趋势减少      趋势减少
# 13   NEARUSDT -0.001137 -0.0341  0.065795  0.360377      趋势增加      趋势增加
# 14  MATICUSDT -0.007153 -0.2146  0.051642  0.282855      趋势减少      趋势减少
# 15    ICPUSDT -0.009267 -0.2780  0.050722  0.277817      趋势增加      趋势减少
# 16    LTCUSDT -0.007457 -0.2237  0.039402  0.215812      趋势减少      趋势减少
# 17    DAIUSDT -0.000630 -0.0189  0.011212  0.061411      趋势减少      趋势增加
# 18    UNIUSDT -0.013253 -0.3976  0.053773  0.294527      趋势减少      趋势减少

# %% [markdown]
# ### 每天收益率走势

# %%
line_daily_return.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="fbe3f58788314613963dbecd22bc442c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_fbe3f58788314613963dbecd22bc442c = echarts.init(
#                     document.getElementById('fbe3f58788314613963dbecd22bc442c'), 'white', {renderer: 'canvas'});
#                 var option_fbe3f58788314613963dbecd22bc442c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "BTC",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2024-04-06T08:00:00",
#                     0.0
#                 ],
#                 [
#                     "2024-04-07T08:00:00",
#                     0.0073
#                 ],
#                 [
#                     "2024-04-08T08:00:00",
#                     0.0327
#                 ],
#                 [
#                     "2024-04-09T08:00:00",
#                     -0.035
#                 ],
#                 [
#                     "2024-04-10T08:00:00",
#                     0.0198
#                 ],
#                 [
#                     "2024-04-11T08:00:00",
#                     -0.0071
#                 ],
#                 [
#                     "2024-04-12T08:00:00",
#                     -0.0419
#                 ],
#                 [
#                     "2024-04-13T08:00:00",
#                     -0.0494
#                 ],
#                 [
#                     "2024-04-14T08:00:00",
#                     0.0283
#                 ],
#                 [
#                     "2024-04-15T08:00:00",
#                     -0.0361
#                 ],
#                 [
#                     "2024-04-16T08:00:00",
#                     0.0064
#                 ],
#                 [
#                     "2024-04-17T08:00:00",
#                     -0.0411
#                 ],
#                 [
#                     "2024-04-18T08:00:00",
#                     0.0349
#                 ],
#                 [
#                     "2024-04-19T08:00:00",
#                     0.006
#                 ],
#                 [
#                     "2024-04-20T08:00:00",
#                     0.0169
#                 ],
#                 [
#                     "2024-04-21T08:00:00",
#                     0.0004
#                 ],
#                 [
#                     "2024-04-22T08:00:00",
#                     0.0287
#                 ],
#                 [
#                     "2024-04-23T08:00:00",
#                     -0.0068
#                 ],
#                 [
#                     "2024-04-24T08:00:00",
#                     -0.0325
#                 ],
#                 [
#                     "2024-04-25T08:00:00",
#                     0.0034
#                 ],
#                 [
#                     "2024-04-26T08:00:00",
#                     -0.0109
#                 ],
#                 [
#                     "2024-04-27T08:00:00",
#                     -0.0054
#                 ],
#                 [
#                     "2024-04-28T08:00:00",
#                     -0.0051
#                 ],
#                 [
#                     "2024-04-29T08:00:00",
#                     0.0107
#                 ],
#                 [
#                     "2024-04-30T08:00:00",
#                     -0.0501
#                 ],
#                 [
#                     "2024-05-01T08:00:00",
#                     -0.0393
#                 ],
#                 [
#                     "2024-05-02T08:00:00",
#                     0.0126
#                 ],
#                 [
#                     "2024-05-03T08:00:00",
#                     0.0615
#                 ],
#                 [
#                     "2024-05-04T08:00:00",
#                     0.015
#                 ],
#                 [
#                     "2024-05-05T08:00:00",
#                     -0.0079
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "ETH",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2024-04-06T08:00:00",
#                     0.0
#                 ],
#                 [
#                     "2024-04-07T08:00:00",
#                     0.0289
#                 ],
#                 [
#                     "2024-04-08T08:00:00",
#                     0.0681
#                 ],
#                 [
#                     "2024-04-09T08:00:00",
#                     -0.0522
#                 ],
#                 [
#                     "2024-04-10T08:00:00",
#                     0.0094
#                 ],
#                 [
#                     "2024-04-11T08:00:00",
#                     -0.0094
#                 ],
#                 [
#                     "2024-04-12T08:00:00",
#                     -0.0779
#                 ],
#                 [
#                     "2024-04-13T08:00:00",
#                     -0.0772
#                 ],
#                 [
#                     "2024-04-14T08:00:00",
#                     0.0498
#                 ],
#                 [
#                     "2024-04-15T08:00:00",
#                     -0.0182
#                 ],
#                 [
#                     "2024-04-16T08:00:00",
#                     -0.0046
#                 ],
#                 [
#                     "2024-04-17T08:00:00",
#                     -0.0333
#                 ],
#                 [
#                     "2024-04-18T08:00:00",
#                     0.0269
#                 ],
#                 [
#                     "2024-04-19T08:00:00",
#                     -0.0019
#                 ],
#                 [
#                     "2024-04-20T08:00:00",
#                     0.03
#                 ],
#                 [
#                     "2024-04-21T08:00:00",
#                     -0.0026
#                 ],
#                 [
#                     "2024-04-22T08:00:00",
#                     0.0172
#                 ],
#                 [
#                     "2024-04-23T08:00:00",
#                     0.0067
#                 ],
#                 [
#                     "2024-04-24T08:00:00",
#                     -0.0248
#                 ],
#                 [
#                     "2024-04-25T08:00:00",
#                     0.0052
#                 ],
#                 [
#                     "2024-04-26T08:00:00",
#                     -0.0086
#                 ],
#                 [
#                     "2024-04-27T08:00:00",
#                     0.0372
#                 ],
#                 [
#                     "2024-04-28T08:00:00",
#                     0.0036
#                 ],
#                 [
#                     "2024-04-29T08:00

# %% [markdown]
# ### 累计收益率走势

# %%
line_accumulative_return.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5eebff29021249ddb75bec96a238495e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5eebff29021249ddb75bec96a238495e = echarts.init(
#                     document.getElementById('5eebff29021249ddb75bec96a238495e'), 'white', {renderer: 'canvas'});
#                 var option_5eebff29021249ddb75bec96a238495e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "BTC",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2024-04-06T08:00:00",
#                     0.0
#                 ],
#                 [
#                     "2024-04-07T08:00:00",
#                     0.0073
#                 ],
#                 [
#                     "2024-04-08T08:00:00",
#                     0.04
#                 ],
#                 [
#                     "2024-04-09T08:00:00",
#                     0.005
#                 ],
#                 [
#                     "2024-04-10T08:00:00",
#                     0.0248
#                 ],
#                 [
#                     "2024-04-11T08:00:00",
#                     0.0177
#                 ],
#                 [
#                     "2024-04-12T08:00:00",
#                     -0.0242
#                 ],
#                 [
#                     "2024-04-13T08:00:00",
#                     -0.0736
#                 ],
#                 [
#                     "2024-04-14T08:00:00",
#                     -0.0453
#                 ],
#                 [
#                     "2024-04-15T08:00:00",
#                     -0.0814
#                 ],
#                 [
#                     "2024-04-16T08:00:00",
#                     -0.075
#                 ],
#                 [
#                     "2024-04-17T08:00:00",
#                     -0.1161
#                 ],
#                 [
#                     "2024-04-18T08:00:00",
#                     -0.0812
#                 ],
#                 [
#                     "2024-04-19T08:00:00",
#                     -0.0752
#                 ],
#                 [
#                     "2024-04-20T08:00:00",
#                     -0.0583
#                 ],
#                 [
#                     "2024-04-21T08:00:00",
#                     -0.0579
#                 ],
#                 [
#                     "2024-04-22T08:00:00",
#                     -0.0292
#                 ],
#                 [
#                     "2024-04-23T08:00:00",
#                     -0.036
#                 ],
#                 [
#                     "2024-04-24T08:00:00",
#                     -0.0685
#                 ],
#                 [
#                     "2024-04-25T08:00:00",
#                     -0.0651
#                 ],
#                 [
#                     "2024-04-26T08:00:00",
#                     -0.076
#                 ],
#                 [
#                     "2024-04-27T08:00:00",
#                     -0.0814
#                 ],
#                 [
#                     "2024-04-28T08:00:00",
#                     -0.0865
#                 ],
#                 [
#                     "2024-04-29T08:00:00",
#                     -0.0758
#                 ],
#                 [
#                     "2024-04-30T08:00:00",
#                     -0.1259
#                 ],
#                 [
#                     "2024-05-01T08:00:00",
#                     -0.1652
#                 ],
#                 [
#                     "2024-05-02T08:00:00",
#                     -0.1526
#                 ],
#                 [
#                     "2024-05-03T08:00:00",
#                     -0.0911
#                 ],
#                 [
#                     "2024-05-04T08:00:00",
#                     -0.0761
#                 ],
#                 [
#                     "2024-05-05T08:00:00",
#                     -0.084
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "ETH",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2024-04-06T08:00:00",
#                     0.0
#                 ],
#                 [
#                     "2024-04-07T08:00:00",
#                     0.0289
#                 ],
#                 [
#                     "2024-04-08T08:00:00",
#                     0.097
#                 ],
#                 [
#                     "2024-04-09T08:00:00",
#                     0.0448
#                 ],
#                 [
#                     "2024-04-10T08:00:00",
#                     0.0542
#                 ],
#                 [
#                     "2024-04-11T08:00:00",
#                     0.0448
#                 ],
#                 [
#                     "2024-04-12T08:00:00",
#                     -0.0331
#                 ],
#                 [
#                     "2024-04-13T08:00:00",
#                     -0.1103
#                 ],
#                 [
#                     "2024-04-14T08:00:00",
#                     -0.0605
#                 ],
#                 [
#                     "2024-04-15T08:00:00",
#                     -0.0787
#                 ],
#                 [
#                     "2024-04-16T08:00:00",
#                     -0.0833
#                 ],
#                 [
#                     "2024-04-17T08:00:00",
#                     -0.1166
#                 ],
#                 [
#                     "2024-04-18T08:00:00",
#                     -0.0897
#                 ],
#                 [
#                     "2024-04-19T08:00:00",
#                     -0.0916
#                 ],
#                 [
#                     "2024-04-20T08:00:00",
#                     -0.0616
#                 ],
#                 [
#                     "2024-04-21T08:00:00",
#                     -0.0642
#                 ],
#                 [
#                     "2024-04-22T08:00:00",
#                     -0.047
#                 ],
#                 [
#                     "2024-04-23T08:00:00",
#                     -0.0403
#                 ],
#                 [
#                     "2024-04-24T08:00:00",
#                     -0.0651
#                 ],
#                 [
#                     "2024-04-25T08:00:00",
#                     -0.0599
#                 ],
#                 [
#                     "2024-04-26T08:00:00",
#                     -0.0685
#                 ],
#                 [
#                     "2024-04-27T08:00:00",
#                     -0.0313
#                 ],
#                 [
#                     "2024-04-28T08:00:00",
#                     -0.0277
#                 ],
#                 [
#                     "2024

# %% [markdown]
# ## 近期表现最好和最差的货币

# %% [markdown]
# ### 涨幅大的

# %%
analysis=Analysis()
plot = Plot()
end_date=datetime.today()
days_range=10
start_date=end_date+timedelta(days=-days_range)
freq='1d'
n=10

best_n=analysis.best_performed_of_last_n(interval=freq, num=n, start=start_date, end=end_date)
line_best_n=plot.plot_top_return_markets(interval=freq, num=10, start=start_date, end=end_date)

# %%
best_n
# Out:
#      symbol  return
# 0   GLMUSDT  0.5194
# 1    OPUSDT  0.2369
# 2   LSKUSDT  0.1020
# 3  RNDRUSDT  0.0826
# 4  AVAXUSDT  0.0795
# 5   IMXUSDT  0.0786
# 6   GRTUSDT  0.0696
# 7   XNOUSDT  0.0663
# 8  DOGEUSDT  0.0619
# 9   ENSUSDT  0.0610

# %%
line_best_n.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="90eea3e38c1549f98fe0a3abf51e8b0b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_90eea3e38c1549f98fe0a3abf51e8b0b = echarts.init(
#                     document.getElementById('90eea3e38c1549f98fe0a3abf51e8b0b'), 'white', {renderer: 'canvas'});
#                 var option_90eea3e38c1549f98fe0a3abf51e8b0b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "GLM",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2024-04-26T08:00:00",
#                     0.0
#                 ],
#                 [
#                     "2024-04-27T08:00:00",
#                     0.2719
#                 ],
#                 [
#                     "2024-04-28T08:00:00",
#                     0.3304
#                 ],
#                 [
#                     "2024-04-29T08:00:00",
#                     0.3381
#                 ],
#                 [
#                     "2024-04-30T08:00:00",
#                     0.2723
#                 ],
#                 [
#                     "2024-05-01T08:00:00",
#                     0.1841
#                 ],
#                 [
#                     "2024-05-02T08:00:00",
#                     0.1476
#                 ],
#                 [
#                     "2024-05-03T08:00:00",
#                     0.1848
#                 ],
#                 [
#                     "2024-05-04T08:00:00",
#                     0.4037
#                 ],
#                 [
#                     "2024-05-05T08:00:00",
#                     0.4183
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "OP",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2024-04-26T08:00:00",
#                     0.0
#                 ],
#                 [
#                     "2024-04-27T08:00:00",
#                     0.1179
#                 ],
#                 [
#                     "2024-04-28T08:00:00",
#                     0.124
#                 ],
#                 [
#                     "2024-04-29T08:00:00",
#                     0.0701
#                 ],
#                 [
#                     "2024-04-30T08:00:00",
#                     0.0868
#                 ],
#                 [
#                     "2024-05-01T08:00:00",
#                     0.1862
#                 ],
#                 [
#                     "2024-05-02T08:00:00",
#                     0.2126
#                 ],
#                 [
#                     "2024-05-03T08:00:00",
#                     0.2084
#                 ],
#                 [
#                     "2024-05-04T08:00:00",
#                     0.2161
#                 ],
#                 [
#                     "2024-05-05T08:00:00",
#                     0.2126
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "LSK",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2024-04-26T08:00:00",
#                     0.0
#                 ],
#                 [
#                     "2024-04-27T08:00:00",
#                     -0.033
#                 ],
#                 [
#                     "2024-04-28T08:00:00",
#                     -0.0354
#                 ],
#                 [
#                     "2024-04-29T08:00:00",
#                     -0.0223
#                 ],
#                 [
#                     "2024-04-30T08:00:00",
#                     -0.0778
#                 ],
#                 [
#                     "2024-05-01T08:00:00",
#                     -0.0053
#                 ],
#                 [
#                     "2024-05-02T08:00:00",
#                     0.0392
#                 ],
#                 [
#                     "2024-05-03T08:00:00",
#                     0.0855
#                 ],
#                 [
#                     "2024-05-04T08:00:00",
#                     0.1297
#                 ],
#                 [
#                     "2024-05-05T08:00:00",
#                     0.0971
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "RNDR",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2024-04-26T08:00:00",
#                     0.0
#                 ],
#                 [
#                     "2024-04-27T08:00:00",
#                     -0.0169
#                 ],
#                 [
#                     "2024-04-28T08:00:00",
#                     -0.0339
#                 ],
#                 [
#                     "2024-04-29T08:00:00",
#                     -0.0402
#                 ],
#                 [
#                     "2024-04-30T08:00:00",
#                     -0.116
#                 ],
#                 [
#                     "2024-05-01T08:00:00",
#                     -0.066
#                 ],
#                 [
#                     "2024-05-02T08:00:00",
#                     -0.049
#                 ],
#                 [
#                     "2024-05-03T08:00:0

# %% [markdown]
# ### 跌幅大的

# %%
worst_n=analysis.worst_performed_of_last_n(interval=freq, num=n, start=start_date, end=end_date)
line_worst_n=plot.plot_worst_return_markets(interval=freq, num=10, start=start_date, end=end_date)

# %%
worst_n
# Out:
#       symbol  return
# 0    ACHUSDT -0.1601
# 1   FORTUSDT -0.1485
# 2   VITEUSDT -0.1478
# 3    SYSUSDT -0.1335
# 4  1INCHUSDT -0.0990
# 5  THETAUSDT -0.0965
# 6    NEOUSDT -0.0863
# 7    SUIUSDT -0.0853
# 8  LAZIOUSDT -0.0798
# 9    LTCUSDT -0.0752

# %%
line_worst_n.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4c2ac750faee408c8d93e4b3f23dc295" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4c2ac750faee408c8d93e4b3f23dc295 = echarts.init(
#                     document.getElementById('4c2ac750faee408c8d93e4b3f23dc295'), 'white', {renderer: 'canvas'});
#                 var option_4c2ac750faee408c8d93e4b3f23dc295 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "ACH",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2024-04-26T08:00:00",
#                     0.0
#                 ],
#                 [
#                     "2024-04-27T08:00:00",
#                     -0.023
#                 ],
#                 [
#                     "2024-04-28T08:00:00",
#                     -0.0585
#                 ],
#                 [
#                     "2024-04-29T08:00:00",
#                     -0.0789
#                 ],
#                 [
#                     "2024-04-30T08:00:00",
#                     -0.1715
#                 ],
#                 [
#                     "2024-05-01T08:00:00",
#                     -0.2149
#                 ],
#                 [
#                     "2024-05-02T08:00:00",
#                     -0.182
#                 ],
#                 [
#                     "2024-05-03T08:00:00",
#                     -0.126
#                 ],
#                 [
#                     "2024-05-04T08:00:00",
#                     -0.1594
#                 ],
#                 [
#                     "2024-05-05T08:00:00",
#                     -0.1745
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "FORT",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2024-04-26T08:00:00",
#                     0.0
#                 ],
#                 [
#                     "2024-04-27T08:00:00",
#                     -0.0663
#                 ],
#                 [
#                     "2024-04-28T08:00:00",
#                     -0.0752
#                 ],
#                 [
#                     "2024-04-29T08:00:00",
#                     -0.1693
#                 ],
#                 [
#                     "2024-04-30T08:00:00",
#                     -0.2586
#                 ],
#                 [
#                     "2024-05-01T08:00:00",
#                     -0.2089
#                 ],
#                 [
#                     "2024-05-02T08:00:00",
#                     -0.1438
#                 ],
#                 [
#                     "2024-05-03T08:00:00",
#                     -0.1041
#                 ],
#                 [
#                     "2024-05-04T08:00:00",
#                     -0.1576
#                 ],
#                 [
#                     "2024-05-05T08:00:00",
#                     -0.1607
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "VITE",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2024-04-26T08:00:00",
#                     0.0
#                 ],
#                 [
#                     "2024-04-27T08:00:00",
#                     0.0
#                 ],
#                 [
#                     "2024-04-28T08:00:00",
#                     -0.1461
#                 ],
#                 [
#                     "2024-04-29T08:00:00",
#                     -0.0666
#                 ],
#                 [
#                     "2024-04-30T08:00:00",
#                     -0.2432
#                 ],
#                 [
#                     "2024-05-01T08:00:00",
#                     -0.1845
#                 ],
#                 [
#                     "2024-05-02T08:00:00",
#                     -0.2475
#                 ],
#                 [
#                     "2024-05-03T08:00:00",
#                     -0.2556
#                 ],
#                 [
#                     "2024-05-04T08:00:00",
#                     -0.1599
#                 ],
#                 [
#                     "2024-05-05T08:00:00",
#                     -0.1599
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "SYS",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2024-04-26T08:00:00",
#                     0.0
#                 ],
#                 [
#                     "2024-04-27T08:00:00",
#                     -0.0065
#                 ],
#                 [
#                     "2024-04-28T08:00:00",
#                     -0.0333
#                 ],
#                 [
#                     "2024-04-29T08:00:00",
#                     -0.0957
#                 ],
#                 [
#                     "2024-04-30T08:00:00",
#                     -0.2488
#                 ],
#                 [
#                     "2024-05-01T08:00:00",
#                     -0.2494
#                 ],
#                 [
#                     "2024-05-02T08:00:00",
#                     -0.1653
#                 ],
#                 [

# %% [markdown]
# ## 与BTC相关性

# %% [markdown]
# ### Pearson相关系数矩阵

# %%
plot=Plot()
analysis=Analysis()
win=30
end_date=datetime.today()
days_range=100
start_date=end_date+timedelta(days=-days_range)
freq='1d'
markets = TOP_VALUABLE_MARKETS[:7].copy()

matrix=analysis.yield_corr_matrix(markets=markets, interval=freq, start=start_date,end=end_date)

# %%
c = plot.plot_corr_matrix(markets=markets, interval=freq, start=start_date,end=end_date)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="0d8fb79fa51f40cfa484155a36d1f336" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_0d8fb79fa51f40cfa484155a36d1f336 = echarts.init(
#                     document.getElementById('0d8fb79fa51f40cfa484155a36d1f336'), 'white', {renderer: 'canvas'});
#                 var option_0d8fb79fa51f40cfa484155a36d1f336 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "name": "\u76f8\u5173\u7cfb\u6570*100",
#             "data": [
#                 [
#                     0,
#                     0,
#                     100.0
#                 ],
#                 [
#                     0,
#                     1,
#                     84.54
#                 ],
#                 [
#                     0,
#                     2,
#                     60.07
#                 ],
#                 [
#                     0,
#                     3,
#                     71.22
#                 ],
#                 [
#                     0,
#                     4,
#                     60.49
#                 ],
#                 [
#                     0,
#                     5,
#                     78.8
#                 ],
#                 [
#                     0,
#                     6,
#                     72.96
#                 ],
#                 [
#                     1,
#                     0,
#                     84.54
#                 ],
#                 [
#                     1,
#                     1,
#                     100.0
#                 ],
#                 [
#                     1,
#                     2,
#                     55.73
#                 ],
#                 [
#                     1,
#                     3,
#                     70.46
#                 ],
#                 [
#                     1,
#                     4,
#                     64.77
#                 ],
#                 [
#                     1,
#                     5,
#                     71.01
#                 ],
#                 [
#                     1,
#                     6,
#                     78.43
#                 ],
#                 [
#                     2,
#                     0,
#                     60.07
#                 ],
#                 [
#                     2,
#                     1,
#                     55.73
#                 ],
#                 [
#                     2,
#                     2,
#                     100.0
#                 ],
#                 [
#                     2,
#                     3,
#                     55.14
#                 ],
#                 [
#                     2,
#                     4,
#                     36.34
#                 ],
#                 [
#                     2,
#                     5,
#                     40.66
#                 ],
#                 [
#                     2,
#                     6,
#                     49.88
#                 ],
#                 [
#                     3,
#                     0,
#                     71.22
#                 ],
#                 [
#                     3,
#                     1,
#                     70.46
#                 ],
#                 [
#                     3,
#                     2,
#                     55.14
#                 ],
#                 [
#                     3,
#                     3,
#                     100.0
#                 ],
#                 [
#                     3,
#                     4,
#                     53.36
#                 ],
#                 [
#                     3,
#                     5,
#                     59.17
#                 ],
#                 [
#                     3,
#                     6,
#                     72.67
#                 ],
#                 [
#                     4,
#                     0,
#                     60.49
#                 ],
#                 [
#                     4,
#                     1,
#                     64.77
#                 ],
#                 [
#                     4,
#                     2,
#                     36.34
#                 ],
#                 [
#                     4,
#                     3,
#                     53.36
#                 ],
#                 [
#                     4,
#                     4,
#                     100.0
#                 ],
#                 [
#                     4,
#                     5,
#                     57.58
#                 ],
#                 [
#                     4,
#                     6,
#                     80.45
#                 ],
#                 [
#                     5,
#                     0,
#                     78.8
#                 ],
#                 [
#                     5,
#                     1,
#                     71.01
#                 ],
#                 [
#                     5,
#                     2,
#                     40.66
#                 ],
#                 [
#                     5,
#                     3,
#                     59.17
#                 ],
#                 [
#                     5,
#                     4,
#                     57.58
#                 ],
#                 [
#                     5,
#                     5,
#                     100.0
#                 ],
#                 [
#                     5,
#                     6,
#                     71.6
#                 ],
#                 [
#                     6,
#                     0,
#                     72.96
#                 ],
#                 [
#                     6,
#                     1,
#                     78.43
#                 ],
#                 [
#                     6,
#                     2,
#                     49.88
#                 ],
#                 [
#                     6,
#                     3,
#                     72.67
#                 ],
#                 [
#                     6,
#                     4,
#                     80.45
#                 ],
#                 [
#                     6,
#                     5,
#                     71.6
#                 ],
#                 [
#                     6,
#                     6,
#                     100.0
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "middle",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u76f8\u5173\u7cfb\u6570*100"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14

# %% [markdown]
# ### 相关系数走势

# %%
df=analysis.yield_corr_to_btc(markets=markets, interval=freq, start=start_date,end=end_date,window=30)
line=plot.pyecharts_line_plot(df)
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="72d19b0e9c5f40c2ae08b16aaa49f18a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_72d19b0e9c5f40c2ae08b16aaa49f18a = echarts.init(
#                     document.getElementById('72d19b0e9c5f40c2ae08b16aaa49f18a'), 'white', {renderer: 'canvas'});
#                 var option_72d19b0e9c5f40c2ae08b16aaa49f18a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "BTC",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2024-02-25T08:00:00",
#                     1.0000000000000002
#                 ],
#                 [
#                     "2024-02-26T08:00:00",
#                     0.9999999999999998
#                 ],
#                 [
#                     "2024-02-27T08:00:00",
#                     0.9999999999999997
#                 ],
#                 [
#                     "2024-02-28T08:00:00",
#                     1.0
#                 ],
#                 [
#                     "2024-02-29T08:00:00",
#                     1.0
#                 ],
#                 [
#                     "2024-03-01T08:00:00",
#                     1.0000000000000002
#                 ],
#                 [
#                     "2024-03-02T08:00:00",
#                     1.0
#                 ],
#                 [
#                     "2024-03-03T08:00:00",
#                     1.0000000000000002
#                 ],
#                 [
#                     "2024-03-04T08:00:00",
#                     1.0000000000000002
#                 ],
#                 [
#                     "2024-03-05T08:00:00",
#                     1.0000000000000002
#                 ],
#                 [
#                     "2024-03-06T08:00:00",
#                     1.0000000000000002
#                 ],
#                 [
#                     "2024-03-07T08:00:00",
#                     1.0
#                 ],
#                 [
#                     "2024-03-08T08:00:00",
#                     1.0
#                 ],
#                 [
#                     "2024-03-09T08:00:00",
#                     1.0000000000000004
#                 ],
#                 [
#                     "2024-03-10T08:00:00",
#                     1.0000000000000002
#                 ],
#                 [
#                     "2024-03-11T08:00:00",
#                     1.0000000000000002
#                 ],
#                 [
#                     "2024-03-12T08:00:00",
#                     1.0000000000000002
#                 ],
#                 [
#                     "2024-03-13T08:00:00",
#                     1.0
#                 ],
#                 [
#                     "2024-03-14T08:00:00",
#                     1.0000000000000002
#                 ],
#                 [
#                     "2024-03-15T08:00:00",
#                     1.0
#                 ],
#                 [
#                     "2024-03-16T08:00:00",
#                     1.0000000000000002
#                 ],
#                 [
#                     "2024-03-17T08:00:00",
#                     1.0000000000000004
#                 ],
#                 [
#                     "2024-03-18T08:00:00",
#                     1.0000000000000004
#                 ],
#                 [
#                     "2024-03-19T08:00:00",
#                     1.0000000000000004
#                 ],
#                 [
#                     "2024-03-20T08:00:00",
#                     1.0000000000000004
#                 ],
#                 [
#                     "2024-03-21T08:00:00",
#                     1.0000000000000002
#                 ],
#                 [
#                     "2024-03-22T08:00:00",
#                     1.0000000000000002
#                 ],
#                 [
#                     "2024-03-23T08:00:00",
#                     1.0000000000000002
#                 ],
#                 [
#                     "2024-03-24T08:00:00",
#                     1.0000000000000002
#                 ],
#                 [
#                     "2024-03-25T08:00:00",
#                     1.0000000000000002
#                 ],
#                 [
#                     "2024-03-26T08:00:00",
#                     1.0000000000000002
#                 ],
#                 [
#                     "2024-03-27T08:00:00",
#                     1.0000000000000002
#                 ],
#                 [
#                     "2024-03-28T08:00:00",
#                     1.0
#                 ],
#                 [
#                     "2024-03-29T08:00:00",
#                     1.0000000000000002
#                 ],
#                 [
#                     "2024-03-30T08:00:00",
#                     1.0
#                 ],
#                 [
#                     "2024-03-31T08:00:00",
#                     1.0000000000000002
#                 ],
#                 [
#                     "2024-04-01T08:00:00",
#                     1.0000000000000002
#                 ],
#                 [
#                     "2024-04-02T08:00:00",
#                     1.0000000000000002
#                 ],
#                 [
#                     "2024-04-03T08:00:00",
#                     1.0000000000000004
#                 ],
#                 [
#                     "2024-04-04T08:00:00",
#                     1.0000000000000002
#                 ],
#                 [
#                     "2024-04-05T08:00:00",
#                     1.0000000000000007
#                 ],
#                 [
#                     "2024-04-06T08:00:00",
#                     1.0000000000000004
#                 ],
#                 [
#                     "2024-04-07T08:00:00",
#                     1.0000000000000004
#                 ],
#                 [
#                     "2024-04-08T08:00:00",
#                     1.0000000000000002
#                 ],
#                 [
#                     "2024-04-09T08:00:00",
#                     1.0000000000000007
#                 ],
#                 [
#                     "2024-04-10T08:00:00",
#                     1.0000000000000004
#                 ],
#                 [
#                     "2024-04-11T08:00:00",
#                     1.0000000000000004
#                 ],
#                 [
#                     "2024-04-12T08:00:00",
#                     1.0000000000000009
#                 ],
#                 [
#                     "2024-04-13T08:00:00",
#                     1.0000000000000007
#                 ],
#                 [
#                     "2024-04-14T08:00:00",
#                     1.0000000000000007
#                 ],
#                 [
#                     "2024-04-15T08:00:00",
#                     1.0000000000000009
#                 ],
#                 [
#                     "2024-04-16T08:00:00",
#                     1.0000000000000009
#                 ],
#                 [
#                     "2024-04-17T08:00:00",
#                     1.0000000000000009
#                 ],
#                 [
#                     "2024-04-18T08:00:00",
#                     1.0000000000000009
#                 ],
#                 [
#                     "2024-04-19T08:00:00",
#                     1.0000000000000013
#                 ],
#                 [
#                     "2024-04-20T08:00:00",
#                     1.000000000000001
#                 ],
#                 [
#                     "2024-04-21T08:00:00",

# %% [markdown]
# ## 收益波动分析

# %%
end_date=datetime.today()
days_range=30
start_date=end_date+timedelta(days=-days_range)
start_str=datetime.strftime(start_date, "%Y-%m-%d")
end_str=datetime.strftime(end_date, "%Y-%m-%d")
freq='1d'
read=Read()
analysis=Analysis()

# %%
merge = analysis.merge_data_for_markets(markets=['BTCUSDT','ETHUSDT'],col='Return',interval=freq, start=start_date,end=end_date)
