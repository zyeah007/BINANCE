# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#分析尝试" data-toc-modified-id="分析尝试-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>分析尝试</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#分析一、" data-toc-modified-id="分析一、-1.0.1"><span class="toc-item-num">1.0.1&nbsp;&nbsp;</span>分析一、</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # 分析尝试

# %% [markdown]
# 目的：
# （1）判断出即将大幅上涨的币；
# （2）判断出即将大幅下跌的币；
# （3）配对交易，做无风险套利

# %%
import os
from DataRead import Read, Analysis
from DataQuery import Ticker, Kline, Query
import pandas as pd
import numpy as np
import time
import requests
from Tactic import MACD, SMA, MultiTacs, Tactic
from datetime import datetime, timedelta
# import talib
# %matplotlib inline
import time
from pyecharts.charts import Line
import datetime
from itertools import *
from statsmodels.tsa.stattools import adfuller as ADF
from tqdm import tqdm
import math

# %%
start='2024-1-1'
end='2024-3-29'
interval='1d'
analysis=Analysis()
mkts=['BTCUSDT', 'ETHUSDT']
res=analysis.lineplot_accumulative_returns(markets=mkts, interval=interval,start=start,end=end)
res.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5acea01dc7094764960aafccf2060448" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5acea01dc7094764960aafccf2060448 = echarts.init(
#                     document.getElementById('5acea01dc7094764960aafccf2060448'), 'white', {renderer: 'canvas'});
#                 var option_5acea01dc7094764960aafccf2060448 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "BTC",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2024-01-01T08:00:00",
#                     0.0
#                 ],
#                 [
#                     "2024-01-02T08:00:00",
#                     0.0214
#                 ],
#                 [
#                     "2024-01-03T08:00:00",
#                     -0.0272
#                 ],
#                 [
#                     "2024-01-04T08:00:00",
#                     0.0032
#                 ],
#                 [
#                     "2024-01-05T08:00:00",
#                     0.0037
#                 ],
#                 [
#                     "2024-01-06T08:00:00",
#                     -0.0012
#                 ],
#                 [
#                     "2024-01-07T08:00:00",
#                     -0.0025
#                 ],
#                 [
#                     "2024-01-08T08:00:00",
#                     0.0637
#                 ],
#                 [
#                     "2024-01-09T08:00:00",
#                     0.0483
#                 ],
#                 [
#                     "2024-01-10T08:00:00",
#                     0.0586
#                 ],
#                 [
#                     "2024-01-11T08:00:00",
#                     0.0522
#                 ],
#                 [
#                     "2024-01-12T08:00:00",
#                     -0.0281
#                 ],
#                 [
#                     "2024-01-13T08:00:00",
#                     -0.0275
#                 ],
#                 [
#                     "2024-01-14T08:00:00",
#                     -0.0539
#                 ],
#                 [
#                     "2024-01-15T08:00:00",
#                     -0.0341
#                 ],
#                 [
#                     "2024-01-16T08:00:00",
#                     -0.0203
#                 ],
#                 [
#                     "2024-01-17T08:00:00",
#                     -0.0281
#                 ],
#                 [
#                     "2024-01-18T08:00:00",
#                     -0.0629
#                 ],
#                 [
#                     "2024-01-19T08:00:00",
#                     -0.054
#                 ],
#                 [
#                     "2024-01-20T08:00:00",
#                     -0.0523
#                 ],
#                 [
#                     "2024-01-21T08:00:00",
#                     -0.057
#                 ],
#                 [
#                     "2024-01-22T08:00:00",
#                     -0.1068
#                 ],
#                 [
#                     "2024-01-23T08:00:00",
#                     -0.0985
#                 ],
#                 [
#                     "2024-01-24T08:00:00",
#                     -0.0936
#                 ],
#                 [
#                     "2024-01-25T08:00:00",
#                     -0.0973
#                 ],
#                 [
#                     "2024-01-26T08:00:00",
#                     -0.0516
#                 ],
#                 [
#                     "2024-01-27T08:00:00",
#                     -0.0444
#                 ],
#                 [
#                     "2024-01-28T08:00:00",
#                     -0.0453
#                 ],
#                 [
#                     "2024-01-29T08:00:00",
#                     -0.0169
#                 ],
#                 [
#                     "2024-01-30T08:00:00",
#                     -0.0237
#                 ],
#                 [
#                     "2024-01-31T08:00:00",
#                     -0.0327
#                 ],
#                 [
#                     "2024-02-01T08:00:00",
#                     -0.0214
#                 ],
#                 [
#                     "2024-02-02T08:00:00",
#                     -0.0188
#                 ],
#                 [
#                     "2024-02-03T08:00:00",
#                     -0.024
#                 ],
#                 [
#                     "2024-02-04T08:00:00",
#                     -0.0334
#                 ],
#                 [
#                     "2024-02-05T08:00:00",
#                     -0.0304
#                 ],
#                 [
#                     "2024-02-06T08:00:00",
#                     -0.021
#                 ],
#                 [
#                     "2024-02-07T08:00:00",
#                     0.0074
#                 ],
#                 [
#                     "2024-02-08T08:00:00",
#                     0.029
#                 ],
#                 [
#                     "2024-02-09T08:00:00",
#                     0.0675
#                 ],
#                 [
#                     "2024-02-10T08:00:00",
#                     0.0819
#                 ],
#                 [
#                     "2024-02-11T08:00:00",
#                     0.0917
#                 ],
#                 [
#                     "2024-02-12T08:00:00",
#                     0.1263
#                 ],
#                 [
#                     "2024-02-13T08:00:00",
#                     0.1221
#                 ],
#                 [
#                     "2024-02-14T08:00:00",
#                     0.1619
#                 ],
#                 [
#                     "2024-02-15T08:00:00",
#                     0.1646
#                 ],
#                 [
#                     "2024-02-16T08:00:00",
#                     0.169
#                 ],
#                 [
#                     "2024-02-17T08:00:00",
#                     0.1601
#                 ],
#                 [
#                     "2024-02-18T08:00:00",
#                     0.1688
#                 ],
#                 [
#                     "2024-02-19T08:00:00",
#                     0.1617
#                 ],
#                 [
#                     "2024-02-20T08:00:00",
#                     0.1713
#                 ],
#                 [
#                     "2024-02-21T08:00:00",
#                     0.1631
#                 ],
#                 [
#                     "2024-02-22T08:00:00",
#                     0.1539
#                 ],
#                 [
#                     "2024-02-23T08:00:00",
#                     0.1423
#                 ],
#                 [
#                     "2024-02-24T08:00:00",
#                     0.1581
#                 ],
#                 [
#                     "2024-02-25T08:00:00",
#                     0.1616
#                 ],
#                 [
#                     "2024-02-26T08:00:00",
#                     0.2133
#                 ],
#                 [
#                     "2024-02-27T08:00:00",
#                     0.2595
#                 ],
#                 [
#                     "2024-02-28T08:00:00",
#                     0.3491
#                 ],
#                 [
#                     "2024-02-29T08:00:00",
#                     0.3282
#                 ],
#                 [
#                     "2024-03-01T08:00:00",
#                     0.3488
#                 ],
#                 [
#                     "2024-03-02T08:00:00

# %%
start='2024-2-1'
end='2024-3-29'
top_10=analysis.plot_top_return_markets(interval=interval, num=10, start=start, end=end)
top_10.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3b5d4c1316a3451a94d50c502118a9d5" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3b5d4c1316a3451a94d50c502118a9d5 = echarts.init(
#                     document.getElementById('3b5d4c1316a3451a94d50c502118a9d5'), 'white', {renderer: 'canvas'});
#                 var option_3b5d4c1316a3451a94d50c502118a9d5 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "FLOKI",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2024-02-01T08:00:00",
#                     0.0
#                 ],
#                 [
#                     "2024-02-02T08:00:00",
#                     0.0018
#                 ],
#                 [
#                     "2024-02-03T08:00:00",
#                     -0.0039
#                 ],
#                 [
#                     "2024-02-04T08:00:00",
#                     -0.0263
#                 ],
#                 [
#                     "2024-02-05T08:00:00",
#                     -0.03
#                 ],
#                 [
#                     "2024-02-06T08:00:00",
#                     -0.0011
#                 ],
#                 [
#                     "2024-02-07T08:00:00",
#                     0.0165
#                 ],
#                 [
#                     "2024-02-08T08:00:00",
#                     0.0207
#                 ],
#                 [
#                     "2024-02-09T08:00:00",
#                     0.1045
#                 ],
#                 [
#                     "2024-02-10T08:00:00",
#                     0.0958
#                 ],
#                 [
#                     "2024-02-11T08:00:00",
#                     0.1042
#                 ],
#                 [
#                     "2024-02-12T08:00:00",
#                     0.1314
#                 ],
#                 [
#                     "2024-02-13T08:00:00",
#                     0.1354
#                 ],
#                 [
#                     "2024-02-14T08:00:00",
#                     0.1854
#                 ],
#                 [
#                     "2024-02-15T08:00:00",
#                     0.1836
#                 ],
#                 [
#                     "2024-02-16T08:00:00",
#                     0.1783
#                 ],
#                 [
#                     "2024-02-17T08:00:00",
#                     0.1777
#                 ],
#                 [
#                     "2024-02-18T08:00:00",
#                     0.1887
#                 ],
#                 [
#                     "2024-02-19T08:00:00",
#                     0.2325
#                 ],
#                 [
#                     "2024-02-20T08:00:00",
#                     0.2054
#                 ],
#                 [
#                     "2024-02-21T08:00:00",
#                     0.167
#                 ],
#                 [
#                     "2024-02-22T08:00:00",
#                     0.1908
#                 ],
#                 [
#                     "2024-02-23T08:00:00",
#                     0.2019
#                 ],
#                 [
#                     "2024-02-24T08:00:00",
#                     0.2435
#                 ],
#                 [
#                     "2024-02-25T08:00:00",
#                     0.2743
#                 ],
#                 [
#                     "2024-02-26T08:00:00",
#                     0.4367
#                 ],
#                 [
#                     "2024-02-27T08:00:00",
#                     0.6018
#                 ],
#                 [
#                     "2024-02-28T08:00:00",
#                     0.6966
#                 ],
#                 [
#                     "2024-02-29T08:00:00",
#                     0.6533
#                 ],
#                 [
#                     "2024-03-01T08:00:00",
#                     1.1387
#                 ],
#                 [
#                     "2024-03-02T08:00:00",
#                     1.5753
#                 ],
#                 [
#                     "2024-03-03T08:00:00",
#                     1.651
#                 ],
#                 [
#                     "2024-03-04T08:00:00",
#                     1.6314
#                 ],
#                 [
#                     "2024-03-05T08:00:00",
#                     1.4225
#                 ],
#                 [
#                     "2024-03-06T08:00:00",
#                     1.5368
#                 ],
#                 [
#                     "2024-03-07T08:00:00",
#                     1.5991
#                 ],
#                 [
#                     "2024-03-08T08:00:00",
#                     2.1268
#                 ],
#                 [
#                     "2024-03-09T08:00:00",
#                     2.1407
#                 ],
#                 [
#                     "2024-03-10T08:00:00",
#                     2.2729
#                 ],
#                 [
#                     "2024-03-11T08:00:00",
#                     2.361
#                 ],
#                 [
#                     "2024-03-12T08:00:00",
#                     2.2623
#                 ],
#                 [
#                     "2024-03-13T08:00:00",
#                     2.2656
#                 ],
#                 [
#                     "2024-03-14T08:00:00",
#                     2.2897
#                 ],
#                 [
#                     "2024-03-15T08:00:00",
#                     2.2487
#                 ],
#                 [
#                     "2024-03-16T08:00:00",
#                     2.0256
#                 ],
#                 [
#                     "2024-03-17T08:00:00",
#                     2.079
#                 ],
#                 [
#                     "2024-03-18T08:00:00",
#                     1.9221
#                 ],
#                 [
#                     "2024-03-19T08:00:00",
#                     1.8379
#                 ],
#                 [
#                     "2024-03-20T08:00:00",
#                     2.1111
#                 ],
#                 [
#                     "2024-03-21T08:00:00",
#                     2.0353
#                 ],
#                 [
#                     "2024-03-22T08:00:00",
#                     2.082
#                 ],
#                 [
#                     "2024-03-23T08:00:00",
#                     2.0975
#                 ],
#                 [
#                     "2024-03-24T08:00:00",
#                     2.1461
#                 ],
#                 [
#                     "2024-03-25T08:00:00",
#                     2.1531
#                 ],
#                 [
#                     "2024-03-26T08:00:00",
#                     2.1512
#                 ],
#                 [
#                     "2024-03-27T08:00:00",
#                     2.0861
#                 ],
#                 [
#                     "2024-03-28T08:00:00",
#                     2.1911
#                 ],
#                 [
#                     "2024-03-29T08:00:00",
#                     2.1463
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"

# %%
start='2023-1-1'
end='2023-7-1'
interval='4h'
num=20
threshold=0.0015
pair=['BTCUSDT','ETHUSDT']
analysis=Analysis()
res=analysis.return_diff(market_pair=pair,interval=interval,start=start,end=end)

# %%
res
# Out:
# {'market_1': 'BTCUSDT',
#  'market_2': 'ETHUSDT',
#  'return_diff': 0.000131,
#  'daily_diff': 0.000785,
#  'p_value': 0.0}

# %%
start='2022-1-1'
end='2023-6-18'
line2=analysis.lineplot_individual_returns(markets=['TRXUSDT','JASMYUSDT'],interval='3d',start=start,end=end)
line2.render_notebook()

# %%
analysis=Analysis()
markets=['BTCUSDT','ETHUSDT']
start='2023-1-1'
end='2023-7-11'
interval='1d'
merge_return=analysis.merge_data_for_markets(markets=markets,start=start,end=end,interval=interval,col='Return')
merge_return['diff']=merge_return[markets[0][:-4]]-merge_return[markets[1][:-4]]
merge_return.dropna(subset=['diff'],inplace=True)

line=analysis.pyecharts_line_plot(df=merge_return[['diff']])
line.render_notebook()

# %%
ADF(merge_return['diff'])

# %%
start='2020-1-1'
end='2023-6-18'
line=analysis.plot_price_to_bench(markets=['ETHUSDT'],interval='1d',start=start,end=end,scaled=False)
line.render_notebook()

# %%
markets=['ETHUSDT', 'BTCUSDT', 'DOGEUSDT']
start='2023-1-1'
end='2023-6-17'
window=1
# line=analysis.plot_price_volatility(markets=markets, interval='3d',start=start, end=end)
line=analysis.plot_high_above_close(markets=markets, interval='1d',start=start, end=end,window=window)
line.render_notebook()

# %%
read=Read()
eth=read.read_kline(market='ETHUSDT',freq_type='1d')['close']
btc=read.read_kline(market='BTCUSDT',freq_type='1d')['close']
eth=eth.loc[start:end].copy()
btc=btc.loc[start:end].copy()
df=eth/btc

# %%
df.plot()

# %% [markdown]
# 最近一个月表现最好的货币

# %%
start='2023-2-1'
end='2023-2-28'
best10=analysis.best_performed_of_last_n(interval='1d',start=start, end=end)

# %%
best10

# %%
tgt_mkts = best10['symbol'].values
start='2023-1-1'
end='2023-6-10'
line=analysis.lineplot_accumulative_returns(markets=tgt_mkts,interval='1d',start=start,end=end)
line.render_notebook()

# %%
line=analysis.lineplot_accumulative_returns(markets=tgt_mkts,interval='1d',start=start,end=end)
line.render_notebook()

# %%
start='2023-1-1'
end='2023-12-31'
market_shares = analysis.turnover_value_share(start=start,end=end)
big10=market_shares.iloc[:10]

# %%
start='2023-1-1'
end='2023-6-10'
big10_markets=big10['symbol'].values
line_big10=analysis.lineplot_accumulative_returns(markets=big10_markets,interval='1d',start=start, end=end)
line_big10.render_notebook()

# %% [markdown]
# 2023年1月表现最好货币，在接下来的表现：

# %% [markdown]
# 计算成交额比重

# %%
sma=talib.SMA(close,timeperiod=12)

# %%
sma_ob=SMA()
df2=sma_ob.sma_algorithm(df=df_kline)

# %%
s_date='2017-10-1'
today=datetime.datetime.today()
e_date=today.strftime('%Y-%m-%d')
short_flag = True
tacs=['SMA','DEA','EMA']

result=pd.DataFrame()
for i in tqdm(range(0,len(usdt_markets))):
    mkt = usdt_markets[i]
    read=Read()
    try:
        path = os.path.join('/Users/zhengye/PycharmProjects/BINANCE/tradeData/kline/1d',mkt+'-1d.json')
        if not os.path.exists(path):
            continue
        df_kline=read.read_kline(freq_type='1d',market=mkt)
        multi_tacs=MultiTacs()
        df_multi_tac_returns=multi_tacs.multi_tac_returns(df_kline,tacs=tacs, start=s_date, end=e_date,short_flag=short_flag)
        df_multi_tac_returns['symbol']=mkt[:-4]
        # result=result.append(df_multi_tac_returns)
        result=pd.concat([result, df_multi_tac_returns.iloc[[0],:]],ignore_index=True)
    except:
        print(mkt)
        continue
reuslt=result.sort_values(by='strategy_diff',ascending=False)

# %%
macd, macdsignal, macdhist = talib.MACD(close, fastperiod=12, slowperiod=26, signalperiod=9)

# %%
analysis.top_n_percent_change_markets()

# %% [markdown]
# ### 分析一、
# 从2020年1月开始，每个月收益表现最好的币，在接下来的1个月、3个月、6个月、1年、至今的表现

# %%
best_of_202001=analysis.best_performed_of_last_n(n=30,interval='1d',end='20200131',num=10)

# %%
start='2023-1-1'
start=datetime.datetime.strptime(start,'%Y-%m-%d')
two_weeks_after=(start+datetime.timedelta(weeks=2)).strftime('%Y-%m-%d')
one_month_after=(start+datetime.timedelta(days=30)).strftime('%Y-%m-%d')
three_month_after=(start+datetime.timedelta(days=30*3)).strftime('%Y-%m-%d')
six_month_after=(start+datetime.timedelta(days=30*6)).strftime('%Y-%m-%d')

start=start
end=two_weeks_after
best7_mkts=analysis.best_performed_of_last_n(interval='1d',start=start,end=end,num=7)['symbol'].values

for end_date in [one_month_after, three_month_after, six_month_after]:
    merge=analysis.merge_data_for_markets(markets=best7_mkts,interval='1d',start=start,end=end_date,col='AccumReturn')
    print(merge)
