# %% [markdown]
# # 分析尝试

# %% [markdown]
# 目的：
# （1）判断出即将大幅上涨的币；
# （2）判断出即将大幅下跌的币；
# （3）配对交易，做无风险套利

# %%
import os
from DataRead import Read, Analysis
from DataQuery import Ticker, Kline, Query
import pandas as pd
import numpy as np
import time
import requests
from Tactic import MACD, SMA, MultiTacs, Tactic
import datetime
# import talib
# %matplotlib inline
import time
from pyecharts.charts import Line
import datetime
from itertools import *
from statsmodels.tsa.stattools import adfuller as ADF
from tqdm import tqdm
import math

# %%
def return_diff_pairs(interval='1d',start=None,end=None,num=10,least_obs=30, daily_diff_threshold=0.02):
    ticker=Ticker()
    total_markets=ticker.top_n_markets(n=num)
    market_pairs=combinations(total_markets,2)
    pair_counts = math.factorial(num)//(math.factorial(2)*math.factorial(num-2))
    analysis=Analysis()
    res=[]
    cols=['market1','market2','return_diff','daily_diff','p_value']
    for pair in tqdm(market_pairs,total=pair_counts,ncols=90,desc='迭代计算中...'):
        mkt_1=pair[0]
        mkt_2=pair[1]
        merge_return=analysis.merge_data_for_markets(markets=pair,start=start,end=end,interval=interval,col='Return')
        merge_return['diff']=merge_return[mkt_1[:-4]]-merge_return[mkt_2[:-4]]
        # ADF检验前，需对待验数据处理：剔除空值，且观测量至少least_obs个
        merge_return.dropna(subset=['diff'], inplace=True)
        if len(merge_return)<least_obs:
            continue
        if len(merge_return.loc[end:end]) == 0:  # 结束日期仍有交易数据
            continue
        adf=ADF(merge_return['diff'])
        p_value=adf[1]
        if p_value<0.001:
            p_value=round(p_value,6)
            diff=merge_return['diff'].mean()
            daily_diff = merge_return['diff'].resample(rule='1D').sum().mean()
            if diff > 0:
                res.append([mkt_1,mkt_2,diff,daily_diff,p_value])
            else:
                res.append([mkt_2,mkt_1,-diff,daily_diff,p_value])
        else:
            continue
    df = pd.DataFrame(res,columns=cols)
    df = df[df['daily_diff']>=daily_diff_threshold]
    df = df.sort_values(by=['return_diff'], ascending=False, ignore_index=True)
    return df

# %%
start='2023-1-1'
end='2023-6-18'
interval='3d'
num=60
threshold=0.0015
df=return_diff_pairs(interval=interval,start=start,end=end,num=num,daily_diff_threshold=threshold)
# Out:
# 迭代计算中...: 100%|██████████████████████████████████| 1770/1770 [00:17<00:00, 99.38it/s]

# %%
df
# Out:
#      market1   market2  return_diff  daily_diff   p_value
# 0    STXUSDT  LUNCUSDT     0.031226    0.010532  0.000001
# 1   LINAUSDT  LUNCUSDT     0.027086    0.009136  0.000055
# 2    STXUSDT  LINKUSDT     0.022965    0.007746  0.000000
# 3    STXUSDT  SANDUSDT     0.022504    0.007590  0.000001
# 4    STXUSDT   FLMUSDT     0.022104    0.007455  0.000000
# 5    STXUSDT  AVAXUSDT     0.020711    0.006985  0.000000
# 6   ARPAUSDT  LUNCUSDT     0.020598    0.006947  0.000000
# 7    MTLUSDT  LUNCUSDT     0.019558    0.006596  0.000000
# 8   LINAUSDT  LINKUSDT     0.018825    0.006349  0.000000
# 9   LINAUSDT  SANDUSDT     0.018363    0.006193  0.000000
# 10   STXUSDT   TRXUSDT     0.017395    0.005867  0.000000
# 11   STXUSDT   LDOUSDT     0.014186    0.004785  0.000221
# 12   TRXUSDT  LUNCUSDT     0.013832    0.004665  0.000000
# 13   SOLUSDT  LUNCUSDT     0.013256    0.004471  0.000400
# 14  LINAUSDT   TRXUSDT     0.013254    0.004470  0.000000
# 15  ARPAUSDT  SANDUSDT     0.011875    0.004005  0.000000
# 16   STXUSDT   MTLUSDT     0.011668    0.003936  0.000000
# 17   ARBUSDT  SANDUSDT     0.011343    0.003867  0.000000
# 18   MTLUSDT  LINKUSDT     0.011296    0.003810  0.000000
# 19   MTLUSDT  SANDUSDT     0.010835    0.003654  0.000000
# 20   STXUSDT  ARPAUSDT     0.010628    0.003585  0.000000
# 21   ARBUSDT   STXUSDT     0.010553    0.003598  0.000000
# 22  AVAXUSDT  LUNCUSDT     0.010516    0.003547  0.000000
# 23   LTCUSDT  LUNCUSDT     0.010484    0.003536  0.000000
# 24  LINAUSDT   LDOUSDT     0.010046    0.003388  0.000000
# 25  TUSDUSDT  LUNCUSDT     0.009347    0.003178  0.000000
# 26  USDCUSDT  LUNCUSDT     0.009288    0.003158  0.000000
# 27   FLMUSDT  LUNCUSDT     0.009123    0.003077  0.000026
# 28  TUSDUSDT  SANDUSDT     0.008735    0.002970  0.000001
# 29  USDCUSDT  SANDUSDT     0.008676    0.002950  0.000001
# 30  LINKUSDT  LUNCUSDT     0.008261    0.002786  0.000000
# 31  LINAUSDT  ARPAUSDT     0.006488    0.002188  0.000000
# 32   ARBUSDT  LUNCUSDT     0.006473    0.002207  0.000001
# 33   ARBUSDT  LINKUSDT     0.006410    0.002185  0.000000
# 34  TUSDUSDT  AVAXUSDT     0.006079    0.002067  0.000000
# 35  USDCUSDT  AVAXUSDT     0.006021    0.002047  0.000000
# 36   MTLUSDT   TRXUSDT     0.005726    0.001931  0.000000
# 37   TRXUSDT  SANDUSDT     0.005109    0.001723  0.000084
# 38  TUSDUSDT  LINKUSDT     0.005082    0.001728  0.000000
# 39  USDCUSDT  LINKUSDT     0.005024    0.001708  0.000000
# 40   SOLUSDT  LINKUSDT     0.004995    0.001685  0.000254
# 41   SOLUSDT  SANDUSDT     0.004533    0.001529  0.000000

# %%
start='2022-1-1'
end='2023-6-18'
line2=analysis.lineplot_individual_returns(markets=['TRXUSDT','JASMYUSDT'],interval='3d',start=start,end=end)
line2.render_notebook()

# %%
analysis=Analysis()
markets=['TOMOUSDT','PEPEUSDT']
start='2023-1-1'
end='2023-6-18'
interval='1d'
merge_return=analysis.merge_data_for_markets(markets=markets,start=start,end=end,interval=interval,col='Return')
merge_return['diff']=merge_return[markets[0][:-4]]-merge_return[markets[1][:-4]]
merge_return.dropna(subset=['diff'],inplace=True)

# line=analysis.pyecharts_line_plot(df=merge_return[['diff']])
# line.render_notebook()

# %%
merge_return['diff'].resample('12H').sum().mean()
# Out:
# 0.01939775280898876

# %%
merge_return
# Out:
#                        TOMO    PEPE    diff
# timestamp
# 2023-05-05 08:00:00  0.0843  0.0000  0.0843
# 2023-05-06 08:00:00 -0.0598 -0.3494  0.2896
# 2023-05-07 08:00:00  0.0371  0.0591 -0.0220
# 2023-05-08 08:00:00 -0.0270 -0.3634  0.3364
# 2023-05-09 08:00:00 -0.0570  0.0354 -0.0924
# 2023-05-10 08:00:00  0.1910 -0.0406  0.2316
# 2023-05-11 08:00:00 -0.0780 -0.3210  0.2430
# 2023-05-12 08:00:00 -0.0200  0.2231 -0.2431
# 2023-05-13 08:00:00 -0.0010  0.0663 -0.0673
# 2023-05-14 08:00:00 -0.0468 -0.0493  0.0025
# 2023-05-15 08:00:00 -0.0024 -0.0285  0.0261
# 2023-05-16 08:00:00  0.0112 -0.0353  0.0465
# 2023-05-17 08:00:00  0.1401 -0.0617  0.2018
# 2023-05-18 08:00:00 -0.0165  0.0127 -0.0292
# 2023-05-19 08:00:00  0.0128 -0.0385  0.0513
# 2023-05-20 08:00:00  0.0245  0.1171 -0.0926
# 2023-05-21 08:00:00 -0.0237 -0.0786  0.0549
# 2023-05-22 08:00:00  0.0604 -0.0450  0.1054
# 2023-05-23 08:00:00  0.1372  0.0450  0.0922
# 2023-05-24 08:00:00 -0.0072 -0.1061  0.0989
# 2023-05-25 08:00:00 -0.0173  0.0000 -0.0173
# 2023-05-26 08:00:00 -0.0100  0.0208 -0.0308
# 2023-05-27 08:00:00  0.0390  0.0403 -0.0013
# 2023-05-28 08:00:00  0.2423 -0.0199  0.2622
# 2023-05-29 08:00:00 -0.1025 -0.0341 -0.0684
# 2023-05-30 08:00:00  0.0131 -0.1023  0.1154
# 2023-05-31 08:00:00 -0.0389 -0.0313 -0.0076
# 2023-06-01 08:00:00 -0.0507 -0.0080 -0.0427
# 2023-06-02 08:00:00  0.0037  0.0315 -0.0278
# 2023-06-03 08:00:00 -0.0220  0.0077 -0.0297
# 2023-06-04 08:00:00  0.0385 -0.0554  0.0939
# 2023-06-05 08:00:00 -0.1097 -0.1775  0.0678
# 2023-06-06 08:00:00  0.1221  0.1528 -0.0307
# 2023-06-07 08:00:00 -0.0868 -0.1147  0.0279
# 2023-06-08 08:00:00  0.1268  0.0093  0.1175
# 2023-06-09 08:00:00 -0.0017  0.0541 -0.0558
# 2023-06-10 08:00:00 -0.0673 -0.1929  0.1256
# 2023-06-11 08:00:00  0.0264 -0.0215  0.0479
# 2023-06-12 08:00:00  0.1009 -0.0109  0.1118
# 2023-06-13 08:00:00 -0.0344  0.0000 -0.0344
# 2023-06-14 08:00:00  0.0438 -0.0335  0.0773
# 2023-06-15 08:00:00  0.0178  0.0113  0.0065
# 2023-06-16 08:00:00 -0.0902  0.0757 -0.1659
# 2023-06-17 08:00:00 -0.0698  0.0408 -0.1106
# 2023-06-18 08:00:00 -0.0842 -0.0619 -0.0223

# %%
start='2020-1-1'
end='2023-6-18'
line=analysis.plot_price_to_bench(markets=['ETHUSDT'],interval='1d',start=start,end=end,scaled=False)
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="865fa444955f4023bf17a6e3094089e6" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_865fa444955f4023bf17a6e3094089e6 = echarts.init(
#                     document.getElementById('865fa444955f4023bf17a6e3094089e6'), 'white', {renderer: 'canvas'});
#                 var option_865fa444955f4023bf17a6e3094089e6 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "ETHUSDT",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2020-01-01T08:00:00",
#                     0.01816035606907518
#                 ],
#                 [
#                     "2020-01-02T08:00:00",
#                     0.01825944519654134
#                 ],
#                 [
#                     "2020-01-03T08:00:00",
#                     0.018291454276129483
#                 ],
#                 [
#                     "2020-01-04T08:00:00",
#                     0.018248299250351162
#                 ],
#                 [
#                     "2020-01-05T08:00:00",
#                     0.018395787328010872
#                 ],
#                 [
#                     "2020-01-06T08:00:00",
#                     0.018580819798917247
#                 ],
#                 [
#                     "2020-01-07T08:00:00",
#                     0.017531625677693095
#                 ],
#                 [
#                     "2020-01-08T08:00:00",
#                     0.017467769284432187
#                 ],
#                 [
#                     "2020-01-09T08:00:00",
#                     0.01761885757557152
#                 ],
#                 [
#                     "2020-01-10T08:00:00",
#                     0.017669836111172108
#                 ],
#                 [
#                     "2020-01-11T08:00:00",
#                     0.017753095070953774
#                 ],
#                 [
#                     "2020-01-12T08:00:00",
#                     0.017903525726391513
#                 ],
#                 [
#                     "2020-01-13T08:00:00",
#                     0.017703326864225176
#                 ],
#                 [
#                     "2020-01-14T08:00:00",
#                     0.018801340747626846
#                 ],
#                 [
#                     "2020-01-15T08:00:00",
#                     0.018863197606731805
#                 ],
#                 [
#                     "2020-01-16T08:00:00",
#                     0.018831400422705938
#                 ],
#                 [
#                     "2020-01-17T08:00:00",
#                     0.019055835786601562
#                 ],
#                 [
#                     "2020-01-18T08:00:00",
#                     0.019531267524753364
#                 ],
#                 [
#                     "2020-01-19T08:00:00",
#                     0.019167518990542077
#                 ],
#                 [
#                     "2020-01-20T08:00:00",
#                     0.019308405699838584
#                 ],
#                 [
#                     "2020-01-21T08:00:00",
#                     0.019401261213617627
#                 ],
#                 [
#                     "2020-01-22T08:00:00",
#                     0.019357640088639494
#                 ],
#                 [
#                     "2020-01-23T08:00:00",
#                     0.019371719027380503
#                 ],
#                 [
#                     "2020-01-24T08:00:00",
#                     0.0192605758976182
#                 ],
#                 [
#                     "2020-01-25T08:00:00",
#                     0.019225281695037993
#                 ],
#                 [
#                     "2020-01-26T08:00:00",
#                     0.019484619849100406
#                 ],
#                 [
#                     "2020-01-27T08:00:00",
#                     0.019093871841590917
#                 ],
#                 [
#                     "2020-01-28T08:00:00",
#                     0.018736512196761115
#                 ],
#                 [
#                     "2020-01-29T08:00:00",
#                     0.018676497307432215
#                 ],
#                 [
#                     "2020-01-30T08:00:00",
#                     0.019414056874598587
#                 ],
#                 [
#                     "2020-01-31T08:00:00",
#                     0.019244319135582694
#                 ],
#                 [
#                     "2020-02-01T08:00:00",
#                     0.019563945651444224
#                 ],
#                 [
#                     "2020-02-02T08:00:00",
#                     0.02019394503140435
#                 ],
#                 [
#                     "2020-02-03T08:00:00",
#                     0.020413807650254405
#                 ],
#                 [
#                     "2020-02-04T08:00:00",
#                     0.020540348939112885
#                 ],
#                 [
#                     "2020-02-05T08:00:00",
#                     0.021200494379965126
#                 ],
#                 [
#                     "2020-02-06T08:00:00",
#                     0.021816414244781007
#                 ],
#                 [
#                     "2020-02-07T08:00:00",
#                     0.022756892639190198
#                 ],
#                 [
#                     "2020-02-08T08:00:00",
#                     0.022541573817211637
#                 ],
#                 [
#                     "2020-02-09T08:00:00",
#                     0.022507449454527546
#                 ],
#                 [
#                     "2020-02-10T08:00:00",
#                     0.022624223113878333
#                 ],
#                 [
#                     "2020-02-11T08:00:00",
#                     0.02315251372384839
#                 ],
#                 [
#                     "2020-02-12T08:00:00",
#                     0.025733891381945026
#                 ],
#                 [
#                     "2020-02-13T08:00:00",
#                     0.02622968768176366
#                 ],
#                 [
#                     "2020-02-14T08:00:00",
#                     0.027565745971717917
#                 ],
#                 [
#                     "2020-02-15T08:00:00",
#                     0.026742805450330753
#                 ],
#                 [
#                     "2020-02-16T08:00:00",
#                     0.026100933018865072
#                 ],
#                 [
#                     "2020-02-17T08:00:00",
#                     0.02759633216567072
#                 ],
#                 [
#                     "2020-02-18T08:00:00",
#                     0.02780305586681765
#                 ],
#                 [
#                     "2020-02-19T08:00:00",
#                     0.026939301360567613
#                 ],
#                 [
#                     "2020-02-20T08:00:00",
#                     0.02677665212652218
#                 ],
#                 [
#                     "2020-02-21T08:00:00",
#                     0.027412279568670206
#                 ],
#                 [
#                     "2020-02-22T08:00:00",
#                     0.02710328405965893
#                 ],
#                 [
#                     "2020-02-23T08:00:00",
#                     0.0276236866470754
#                 ],
#                 [
#                     "2020-02-24T08:00:00",

# %%
markets=['ETHUSDT', 'BTCUSDT', 'DOGEUSDT']
start='2023-1-1'
end='2023-6-17'
window=1
# line=analysis.plot_price_volatility(markets=markets, interval='3d',start=start, end=end)
line=analysis.plot_high_above_close(markets=markets, interval='1d',start=start, end=end,window=window)
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="8097f889e59847f2bdd52a116f17ca88" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_8097f889e59847f2bdd52a116f17ca88 = echarts.init(
#                     document.getElementById('8097f889e59847f2bdd52a116f17ca88'), 'white', {renderer: 'canvas'});
#                 var option_8097f889e59847f2bdd52a116f17ca88 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "ETHUSDT",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2023-01-01T08:00:00",
#                     0.0036073112618092832
#                 ],
#                 [
#                     "2023-01-02T08:00:00",
#                     0.008476112026359114
#                 ],
#                 [
#                     "2023-01-03T08:00:00",
#                     0.004396690132147829
#                 ],
#                 [
#                     "2023-01-04T08:00:00",
#                     0.012491049407271713
#                 ],
#                 [
#                     "2023-01-05T08:00:00",
#                     0.006961094594162619
#                 ],
#                 [
#                     "2023-01-06T08:00:00",
#                     0.005956789637077032
#                 ],
#                 [
#                     "2023-01-07T08:00:00",
#                     0.0055534899174887326
#                 ],
#                 [
#                     "2023-01-08T08:00:00",
#                     0.004526570347863767
#                 ],
#                 [
#                     "2023-01-09T08:00:00",
#                     0.018570270904808412
#                 ],
#                 [
#                     "2023-01-10T08:00:00",
#                     0.009037001542354985
#                 ],
#                 [
#                     "2023-01-11T08:00:00",
#                     0.0061969641353398965
#                 ],
#                 [
#                     "2023-01-12T08:00:00",
#                     0.0155941013616588
#                 ],
#                 [
#                     "2023-01-13T08:00:00",
#                     0.008820286659316397
#                 ],
#                 [
#                     "2023-01-14T08:00:00",
#                     0.032311762049164416
#                 ],
#                 [
#                     "2023-01-15T08:00:00",
#                     0.00910777316878372
#                 ],
#                 [
#                     "2023-01-16T08:00:00",
#                     0.01747688561391045
#                 ],
#                 [
#                     "2023-01-17T08:00:00",
#                     0.027740695082302334
#                 ],
#                 [
#                     "2023-01-18T08:00:00",
#                     0.06521638448356849
#                 ],
#                 [
#                     "2023-01-19T08:00:00",
#                     0.008600403587154934
#                 ],
#                 [
#                     "2023-01-20T08:00:00",
#                     0.006861539203627396
#                 ],
#                 [
#                     "2023-01-21T08:00:00",
#                     0.03233619809917248
#                 ],
#                 [
#                     "2023-01-22T08:00:00",
#                     0.022397139065034682
#                 ],
#                 [
#                     "2023-01-23T08:00:00",
#                     0.013404743311463487
#                 ],
#                 [
#                     "2023-01-24T08:00:00",
#                     0.054943218699589326
#                 ],
#                 [
#                     "2023-01-25T08:00:00",
#                     0.018027966301475205
#                 ],
#                 [
#                     "2023-01-26T08:00:00",
#                     0.01983024064855817
#                 ],
#                 [
#                     "2023-01-27T08:00:00",
#                     0.014634268474355673
#                 ],
#                 [
#                     "2023-01-28T08:00:00",
#                     0.022091470008269207
#                 ],
#                 [
#                     "2023-01-29T08:00:00",
#                     0.009290335133031746
#                 ],
#                 [
#                     "2023-01-30T08:00:00",
#                     0.05192823394202523
#                 ],
#                 [
#                     "2023-01-31T08:00:00",
#                     0.012521052399185115
#                 ],
#                 [
#                     "2023-02-01T08:00:00",
#                     0.003709614541201646
#                 ],
#                 [
#                     "2023-02-02T08:00:00",
#                     0.043551292662739285
#                 ],
#                 [
#                     "2023-02-03T08:00:00",
#                     0.00750216408579399
#                 ],
#                 [
#                     "2023-02-04T08:00:00",
#                     0.017348984025252256
#                 ],
#                 [
#                     "2023-02-05T08:00:00",
#                     0.027495058378657084
#                 ],
#                 [
#                     "2023-02-06T08:00:00",
#                     0.027423820998705304
#                 ],
#                 [
#                     "2023-02-07T08:00:00",
#                     0.0043925004338640945
#                 ],
#                 [
#                     "2023-02-08T08:00:00",
#                     0.02876826039274614
#                 ],
#                 [
#                     "2023-02-09T08:00:00",
#                     0.07171190992331845
#                 ],
#                 [
#                     "2023-02-10T08:00:00",
#                     0.0277252719654211
#                 ],
#                 [
#                     "2023-02-11T08:00:00",
#                     0.0029184080701457962
#                 ],
#                 [
#                     "2023-02-12T08:00:00",
#                     0.021910049312464142
#                 ],
#                 [
#                     "2023-02-13T08:00:00",
#                     0.01385825516196746
#                 ],
#                 [
#                     "2023-02-14T08:00:00",
#                     0.008542723258190771
#                 ],
#                 [
#                     "2023-02-15T08:00:00",
#                     0.0030329806796742095
#                 ],
#                 [
#                     "2023-02-16T08:00:00",
#                     0.06418819909148642
#                 ],
#                 [
#                     "2023-02-17T08:00:00",
#                     0.016606941500823622
#                 ],
#                 [
#                     "2023-02-18T08:00:00",
#                     0.01271562171173208
#                 ],
#                 [
#                     "2023-02-19T08:00:00",
#                     0.027885101949694846
#                 ],
#                 [
#                     "2023-02-20T08:00:00",
#                     0.009757701362673045
#                 ],
#                 [
#                     "2023-02-21T08:00:00",
#                     0.03428206487684972
#                 ],
#                 [
#                     "2023-02-22T08:00:00",
#                     0.014490548583809014
#                 ],
#                 [
#                     "2023-02-23T08:00:00",
#                     0.017249004865103952
#                 ],
#                 [
#                     "2023-02-24T08:00:00",

# %%
read=Read()
eth=read.read_kline(market='ETHUSDT',freq_type='1d')['close']
btc=read.read_kline(market='BTCUSDT',freq_type='1d')['close']
eth=eth.loc[start:end].copy()
btc=btc.loc[start:end].copy()
df=eth/btc

# %%
df.plot()

# %% [markdown]
# 最近一个月表现最好的货币

# %%
start='2023-2-1'
end='2023-2-28'
best10=analysis.best_performed_of_last_n(interval='1d',start=start, end=end)

# %%
best10

# %%
tgt_mkts = best10['symbol'].values
start='2023-1-1'
end='2023-6-10'
line=analysis.lineplot_accumulative_returns(markets=tgt_mkts,interval='1d',start=start,end=end)
line.render_notebook()

# %%
line=analysis.lineplot_accumulative_returns(markets=tgt_mkts,interval='1d',start=start,end=end)
line.render_notebook()

# %%
start='2023-1-1'
end='2023-12-31'
market_shares = analysis.turnover_value_share(start=start,end=end)
big10=market_shares.iloc[:10]

# %%
start='2023-1-1'
end='2023-6-10'
big10_markets=big10['symbol'].values
line_big10=analysis.lineplot_accumulative_returns(markets=big10_markets,interval='1d',start=start, end=end)
line_big10.render_notebook()

# %% [markdown]
# 2023年1月表现最好货币，在接下来的表现：

# %% [markdown]
# 计算成交额比重

# %%
sma=talib.SMA(close,timeperiod=12)

# %%
sma_ob=SMA()
df2=sma_ob.sma_algorithm(df=df_kline)

# %%
s_date='2017-10-1'
today=datetime.datetime.today()
e_date=today.strftime('%Y-%m-%d')
short_flag = True
tacs=['SMA','DEA','EMA']

result=pd.DataFrame()
for i in tqdm(range(0,len(usdt_markets))):
    mkt = usdt_markets[i]
    read=Read()
    try:
        path = os.path.join('/Users/zhengye/PycharmProjects/BINANCE/tradeData/kline/1d',mkt+'-1d.json')
        if not os.path.exists(path):
            continue
        df_kline=read.read_kline(freq_type='1d',market=mkt)
        multi_tacs=MultiTacs()
        df_multi_tac_returns=multi_tacs.multi_tac_returns(df_kline,tacs=tacs, start=s_date, end=e_date,short_flag=short_flag)
        df_multi_tac_returns['symbol']=mkt[:-4]
        # result=result.append(df_multi_tac_returns)
        result=pd.concat([result, df_multi_tac_returns.iloc[[0],:]],ignore_index=True)
    except:
        print(mkt)
        continue
reuslt=result.sort_values(by='strategy_diff',ascending=False)

# %%
macd, macdsignal, macdhist = talib.MACD(close, fastperiod=12, slowperiod=26, signalperiod=9)

# %%
analysis.top_n_percent_change_markets()

# %% [markdown]
# ### 分析一、
# 从2020年1月开始，每个月收益表现最好的币，在接下来的1个月、3个月、6个月、1年、至今的表现

# %%
best_of_202001=analysis.best_performed_of_last_n(n=30,interval='1d',end='20200131',num=10)

# %%
start='2023-1-1'
start=datetime.datetime.strptime(start,'%Y-%m-%d')
two_weeks_after=(start+datetime.timedelta(weeks=2)).strftime('%Y-%m-%d')
one_month_after=(start+datetime.timedelta(days=30)).strftime('%Y-%m-%d')
three_month_after=(start+datetime.timedelta(days=30*3)).strftime('%Y-%m-%d')
six_month_after=(start+datetime.timedelta(days=30*6)).strftime('%Y-%m-%d')

start=start
end=two_weeks_after
best7_mkts=analysis.best_performed_of_last_n(interval='1d',start=start,end=end,num=7)['symbol'].values

for end_date in [one_month_after, three_month_after, six_month_after]:
    merge=analysis.merge_data_for_markets(markets=best7_mkts,interval='1d',start=start,end=end_date,col='AccumReturn')
    print(merge)
